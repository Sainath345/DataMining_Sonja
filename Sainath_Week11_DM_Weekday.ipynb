# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainath345/Rasaputra_IT533/blob/Sainath345-IPL/Sainath_Week11_DM_Weekday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pprint
import requests
import csv
import datetime

# %%
def parse_books(book_list, date):
    '''
    Based on: function parse_articles from 
    This function takes in a response to the NYT books api and parses
    the books into a list of dictionaries
    '''
    books = []
    for i in book_list['results']['books']:
        dic = {}
        dic['age_group'] = i['age_group']
        dic['author'] = i['author'].encode("utf8")        
        dic['book_review_link'] = i['book_review_link'].encode("utf8")
        dic['contributor'] = i['contributor'].encode("utf8")
        dic['dagger'] = i['dagger']
        dic['first_chapter_link'] = i['first_chapter_link'].encode("utf8")
        dic['price'] = i['price']
        dic['primary_isbn10'] = i['primary_isbn10'].encode("utf8")
        dic['primary_isbn13'] = i['primary_isbn13'].encode("utf8")
        dic['publisher'] = i['publisher'].encode("utf8")
        dic['sunday_review_link'] = i['sunday_review_link'].encode("utf8")
        dic['title'] = i['title'].encode("utf8")
        dic['weeks_on_list'] = i['weeks_on_list']
        dic['date'] = date  # add a date so that we know when it was a best-seller
        books.append(dic)
    return(books) 

#sample request: https://api.nytimes.com/svc/books/v3/lists/2017-03-13/Combined%20Print%20and%20E-Book%20Fiction.json?api_key=<your_api_key>
BOOKS_ROOT = "https://api.nytimes.com/svc/books/v3/lists"
LIST = "Combined%20Print%20and%20E-Book%20Fiction.json"   #you can change to other lists available at https://developer.nytimes.com

# Add your API key here 
API_KEY = 'YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu'


bestsellers = []
num_days_to_get = 5 # you can use up to 1000 api calls a day so max=1000

for i in range(0,num_days_to_get):
    day = datetime.datetime.now() - datetime.timedelta(days=i+10)  
    date = str(day.date())
    print(date)
    url = f"%s/%s/%s?api-key=%s" % (BOOKS_ROOT, date, LIST, API_KEY)
    url = url.strip()  
    print(url)
    r = requests.get(url)
    print(r.status_code)
    if (r.status_code == 200):
        results = r.json()
        books = parse_books(results, date)
        bestsellers.extend(books)
# Out:
# 2021-07-22
# https://api.nytimes.com/svc/books/v3/lists/2021-07-22/Combined%20Print%20and%20E-Book%20Fiction.json?api-key=YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu
# 200
# 2021-07-21
# https://api.nytimes.com/svc/books/v3/lists/2021-07-21/Combined%20Print%20and%20E-Book%20Fiction.json?api-key=YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu
# 200
# 2021-07-20
# https://api.nytimes.com/svc/books/v3/lists/2021-07-20/Combined%20Print%20and%20E-Book%20Fiction.json?api-key=YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu
# 200
# 2021-07-19
# https://api.nytimes.com/svc/books/v3/lists/2021-07-19/Combined%20Print%20and%20E-Book%20Fiction.json?api-key=YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu
# 200
# 2021-07-18
# https://api.nytimes.com/svc/books/v3/lists/2021-07-18/Combined%20Print%20and%20E-Book%20Fiction.json?api-key=YgRSuqQ4Zr0V1OuBdOuGr8xKCpIA7vAu
# 200

# %%
r.json()
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'last_modified': '2021-07-07T22:21:32-04:00',
#  'num_results': 15,
#  'results': {'bestsellers_date': '2021-07-03',
#   'books': [{'age_group': '',
#     'amazon_product_url': 'https://www.amazon.com/dp/0063112523?tag=NYTBSREV-20',
#     'article_chapter_link': '',
#     'asterisk': 0,
#     'author': 'Quentin Tarantino',
#     'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780063112520.jpg',
#     'book_image_height': 500,
#     'book_image_width': 316,
#     'book_review_link': 'https://www.nytimes.com/2021/06/28/books/quentin-tarantino-once-upon-time-hollywood-novel.html',
#     'book_uri': 'nyt://book/55d9fe23-d2a1-512c-97f4-021c1fe0a600',
#     'buy_links': [{'name': 'Amazon',
#       'url': 'https://www.amazon.com/dp/0063112523?tag=NYTBSREV-20'},
#      {'name': 'Apple Books',
# ...

# %%
bestsellers[0].keys()
# Out:
# dict_keys(['age_group', 'author', 'book_review_link', 'contributor', 'dagger', 'first_chapter_link', 'price', 'primary_isbn10', 'primary_isbn13', 'publisher', 'sunday_review_link', 'title', 'weeks_on_list', 'date'])

# %%
if (bestsellers[0].keys() is not None):
  keys = bestsellers[0].keys()
  # Print all results to a csv file
  with open('bestsellers.csv', 'wt') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    #dict_writer.writeheader()
    dict_writer.writerows(bestsellers)

# %%
import pandas as pd
import numpy as np

bs_df = pd.read_csv('bestsellers.csv')
for col, dtype in bs_df.dtypes.items():
    if dtype == np.object:
      print(type(col)) # Only process byte object columns.
      bs_df[col] = bs_df[col].apply(lambda x: x.replace("b",''))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
bs_df
# Out:
#     age_group                   author  ... weeks_on_list        date
# 0         NaN  'Miranda Cowley Heller'  ...             1  2021-07-22
# 1         NaN         'Danielle Steel'  ...             1  2021-07-22
# 2         NaN            'T.J. Newman'  ...             1  2021-07-22
# 3         NaN             'Laura Dave'  ...            10  2021-07-22
# 4         NaN            'Emily Henry'  ...             9  2021-07-22
# ..        ...                      ...  ...           ...         ...
# 70        NaN        'Elin Hilderrand'  ...             5  2021-07-18
# 71        NaN    'Taylor Jenkins Reid'  ...             2  2021-07-18
# 72        NaN       'Alex Michaelides'  ...             3  2021-07-18
# 73        NaN        'Madeline Miller'  ...            13  2021-07-18
# 74        NaN         'Colleen Hoover'  ...             3  2021-07-18
#
# [75 rows x 14 columns]
